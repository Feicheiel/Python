# %% [markdown]
# # Credit Union (Non-Residential)

# %% [markdown]
# ## Header Files

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.svm import SVR
from sklearn.model_selection import train_test_split

from datetime import datetime, timedelta
from dateutil.relativedelta import relativedelta

import warnings
import threading
import time

# %%
# Suppress DeprecationWarnings
warnings.filterwarnings("ignore", category=DeprecationWarning)
warnings.filterwarnings('ignore', category=FutureWarning)
pd.options.mode.chained_assignment = None  # default='warn'

# %%
color_pal = sns.color_palette()
plt.style.use('fivethirtyeight')
color_pal
# Out:
# [(0.0, 0.5607843137254902, 0.8352941176470589),
#  (0.9882352941176471, 0.30980392156862746, 0.18823529411764706),
#  (0.8980392156862745, 0.6823529411764706, 0.2196078431372549),
#  (0.42745098039215684, 0.5647058823529412, 0.30980392156862746),
#  (0.5450980392156862, 0.5450980392156862, 0.5450980392156862),
#  (0.5058823529411764, 0.058823529411764705, 0.48627450980392156)]

# %% [markdown]
# ## Read the File

# %%
ccu = pd.read_csv('nr_ccu.csv')

# %% [markdown]
# ## Evaluate Total Power

# %%
phases = [1, 2, 3]
P1 = np.zeros(len(ccu))
P2 = np.zeros(len(ccu))
P3 = np.zeros(len(ccu))
Pn = np.zeros(len(ccu))

P = [P1, P2, P3]

for phase in range(len(phases)):
    for i in range(3, 50, 2):
        P[phase] += (ccu[f"har{i:02}V{phases[phase]}_Avg [V]"] * ccu[f"har{i:02}I{phases[phase]}_Avg [A]"])

# %%
s_pwr = pd.DataFrame({'Datetime':ccu['Time'], 'P1 Harmonic':P1, 'P2 Harmonic':P2, 'P3 Harmonic':P3})
s_pwr.plot()
plt.savefig('ccu_raw', dpi=307)
plt.show()

# %%
s_pwr.head(3)
# Out:
#                 Datetime  P1 Harmonic  P2 Harmonic  P3 Harmonic
# 0  8/24/2023 12:52:00 PM    13.790620    10.642731    11.709476
# 1   8/24/2023 1:02:00 PM    20.340216     9.797805    18.929363
# 2   8/24/2023 1:12:00 PM    39.268085    13.436183    34.882877

# %% [markdown]
# <br><br>
# ## Normalize

# %% [markdown]
# The graph above reveals a zero points which is clearly an error, so we fill it with median.

# %%
for _ in range(20):
    p1_zeroes = s_pwr['P1 Harmonic'] <= 2
    s_pwr['P1 Harmonic'][p1_zeroes] = s_pwr['P1 Harmonic'].rolling(window=10).mean()

    p2_zeroes = s_pwr['P2 Harmonic'] <= 2
    s_pwr['P2 Harmonic'][p2_zeroes] = s_pwr['P2 Harmonic'].rolling(window=10).mean()

    p3_zeroes = s_pwr['P3 Harmonic'] <= 2
    s_pwr['P3 Harmonic'][p3_zeroes] = s_pwr['P3 Harmonic'].rolling(window=10).mean()


s_pwr.plot() 
plt.show()

# %%
s_pwr_ = s_pwr.set_index('Datetime')
s_pwr_.index = pd.to_datetime(s_pwr_.index, format="%m/%d/%Y %I:%M:%S %p")
s_pwr_ = s_pwr_.sort_index()

fig, axe = plt.subplots(figsize=(15, 7))
s_pwr_['P1 Harmonic'].plot(ax=axe, color=color_pal[2], title='Credit Union - Harmonic losses on each phase', legend='P1 Harmonic')
s_pwr_['P2 Harmonic'].plot(ax=axe, color=color_pal[-3], legend='P2 Harmonic')
s_pwr_['P3 Harmonic'].plot(ax=axe, color=color_pal[-6], legend='P3 Harmonic')

axe.legend(['P1 Harmonic', 'P2 Harmonic', 'P3 Harmonic'])
# Add text annotation at a specific point
axe.text(0.15, 0.95, f'Current Harmonics\n\nP1 Harmonic = {s_pwr_['P1 Harmonic'].sum()/6000:>4.2f} kWh\nP2 Harmonic = {s_pwr_['P2 Harmonic'].sum()/6000:>4.2f} kWh\nP3 Harmonic = {s_pwr_['P3 Harmonic'].sum()/6000:>4.2f} kWh', transform=ax.transAxes, fontsize=12,
        verticalalignment='top', bbox=dict(boxstyle='round', facecolor='white', alpha=0.5))
plt.savefig('ccu_harmonics_on_each_phase.jpg', dpi=307)
plt.show()

# %% [markdown]
# ## Separating the Harmonic Power on each phase (using actual data)

# %%
s_p1 = pd.DataFrame({'Datetime':s_pwr['Datetime'], 'P1_Harmonic':s_pwr['P1 Harmonic']})
s_p2 = pd.DataFrame({'Datetime':s_pwr['Datetime'], 'P2_Harmonic':s_pwr['P2 Harmonic']})
s_p3 = pd.DataFrame({'Datetime':s_pwr['Datetime'], 'P3_Harmonic':s_pwr['P3 Harmonic']})

# %%
s_p1 = s_p1.set_index('Datetime')
s_p1.index = pd.to_datetime(s_p1.index, format="%m/%d/%Y %I:%M:%S %p")

s_p2 = s_p2.set_index('Datetime')
s_p2.index = pd.to_datetime(s_p2.index, format="%m/%d/%Y %I:%M:%S %p")

s_p3 = s_p3.set_index('Datetime')
s_p3.index = pd.to_datetime(s_p3.index, format="%m/%d/%Y %I:%M:%S %p")

# %% [markdown]
# ## Feature Creation

# %%
def create_features(df):
    """
    Creates time series features based on time series index.
    """
    df = df.copy()
    df['hour'] = df.index.hour
    df['minute'] = df.index.minute
    df['dayofweek'] = df.index.dayofweek
    
    return df

# %%
s_p1 = create_features(s_p1)   
s_p2 = create_features(s_p2)   
s_p3 = create_features(s_p3)
#s_pn = create_features(s_pn)

s_p2.head()
# Out:
#                      P2_Harmonic  hour  minute  dayofweek
# Datetime
# 2023-08-24 12:52:00    10.642731    12      52          3
# 2023-08-24 13:02:00     9.797805    13       2          3
# 2023-08-24 13:12:00    13.436183    13      12          3
# 2023-08-24 13:22:00    14.659720    13      22          3
# 2023-08-24 13:32:00    10.355018    13      32          3

# %%
set(s_p2['dayofweek'])
# Out:
# {0, 1, 2, 3, 4, 5, 6}

# %% [markdown]
# ## Boxplot of Feature Importance

# %%
s_ps = [s_p1, s_p2, s_p3]
ps = [1, 2, 3]
_2nd_iter = ['hour', 'minute', 'dayofweek']

# Create subplots
fig, axes = plt.subplots(nrows=len(s_ps), ncols=3, figsize=(12, 10))

axes = axes.flatten()

# Set the font style
font_style = {'family': 'arial', 'weight': 'normal', 'size': 9
              #, 'color':'darkred'
             }

# Apply the font style
plt.rc('font', **font_style)

i = 0
for ctr in range(len(s_ps)):
    for b in range(3):
        sns.boxplot(x=_2nd_iter[b], y=f'P{ps[ctr]}_Harmonic', data=s_ps[ctr], ax=axes[i], linewidth=0.7)
        axes[i].set_title(f'Variation of P{ps[ctr]} by the {_2nd_iter[b]}', fontsize=10)
        axes[i].set_ylabel(f'Harmonic, P{ps[ctr]} [W]')
        i += 1

# Adjust layout
plt.tight_layout()

plt.savefig('feature_variations.jpg', dpi=307)

# Show the plot
plt.show()

# %% [markdown]
# ## Model Creation

# %%
def mape(y_true, y_pred):
    """mape: mean_absolute_percentage_error"""
    return np.mean(np.abs((y_true - y_pred)/y_true))*100

# %% [markdown]
# <br>
#
# ### Phase 1 (P1)

# %%
s_p1_ = s_p1_.sort_index()

# %%
sp1__ = s_p1_.loc['2023-08-24 13:22:00':'2023-09-02 00:02:00']

# Make plots.
ax = sp1__[['P1_Harmonic']].plot(figsize=(15,5), color=color_pal[4], title="Credit Union - P1 Phase Prediction vs. True Data")
sp1__['Predictions'].plot(ax=ax, style='-', color=color_pal[3])

accur = f'{p1_accuracy:.2f}%'
ax.set_xlabel('Datetime', rotation=0)
ax.legend(['P1 True Data', 'P1 Predicted'])

# Add text annotation at a specific point
ax.text(0.05, 0.95, f'Accuracy: {accur}', transform=ax.transAxes, fontsize=12,
        verticalalignment='top', bbox=dict(boxstyle='round', facecolor='white', alpha=0.5))

plt.savefig('ccu_p1__true_vs_predicted[shortened].jpg', dpi=307)
plt.show()

# %%
# Create a deep copy
s_p1_ = s_p1.copy(deep=True)

# Create lags
s_p1_['lag_1'] = s_p1_['P1_Harmonic'].shift(1)
s_p1_['lag_2'] = s_p1_['P1_Harmonic'].shift(2)
s_p1_['lag_3'] = s_p1_['P1_Harmonic'].shift(3)

# Create rolling window features
s_p1_['rolling_mean_3'] = s_p1_['P1_Harmonic'].rolling(window=3).mean()
s_p1_['rolling_std_3'] = s_p1_['P1_Harmonic'].rolling(window=3).std()
s_p1_['rolling_var_3'] = s_p1_['P1_Harmonic'].rolling(window=3).sum() 

# Dropna
s_p1_.dropna(inplace=True)

# Sort index
s_p1_ = s_p1_.sort_index()

# Feature creation and extraction.
sp1_X = s_p1_.drop(columns=['P1_Harmonic'])
sp1_y = s_p1_['P1_Harmonic']

# Train the SVR Model
s_p1_SVR = SVR(kernel='rbf', C=1.3, epsilon=0.3)
s_p1_SVR.fit(sp1_X, sp1_y)

# Make predictions
s_p1_['Predictions'] = s_p1_SVR.predict(sp1_X)

# Evaluate Accuracy
p1_accuracy = 100 - mape(s_p1_['P1_Harmonic'], s_p1_['Predictions'])
#print(f'Accuracy (%): {p1_accuracy: .2f}%')

# Make plots.
ax = s_p1_[['P1_Harmonic']].plot(figsize=(15,5), color=color_pal[4], title="Credit Union - P1 Phase Prediction vs. True Data")
s_p1_['Predictions'].plot(ax=ax, style='-', color=color_pal[3])

accur = f'{p1_accuracy:.2f}%'
ax.set_xlabel('Datetime', rotation=0)
ax.legend(['P1 True Data', 'P1 Predicted'])

# Add text annotation at a specific point
ax.text(0.05, 0.95, f'Accuracy: {accur}', transform=ax.transAxes, fontsize=12,
        verticalalignment='top', bbox=dict(boxstyle='round', facecolor='white', alpha=0.5))

plt.savefig('ccu_p1__true_vs_predicted.jpg', dpi=307)
plt.show()

# %%
s_p1_.head(2)
# Out:
#                      P1_Harmonic  hour  minute  dayofweek      lag_1  \
# Datetime
# 2023-08-24 13:22:00    46.550485    13      22          3  39.268085
# 2023-08-24 13:32:00    20.984749    13      32          3  46.550485
#
#                          lag_2      lag_3  rolling_mean_3  rolling_std_3  \
# Datetime
# 2023-08-24 13:22:00  20.340216  13.790620       35.386262      13.529448
# 2023-08-24 13:32:00  39.268085  20.340216       35.601106      13.171437
#
#                      rolling_var_3  Predictions
# Datetime
# 2023-08-24 13:22:00     106.158786    12.531244
# 2023-08-24 13:32:00     106.803319    12.538834

# %% [markdown]
# <br>
#
# ### Phase 2 (P2)

# %%
# Create a deep copy
s_p2_ = s_p2.copy(deep=True)

# Create lags
s_p2_['lag_1'] = s_p2_['P2_Harmonic'].shift(1)
s_p2_['lag_2'] = s_p2_['P2_Harmonic'].shift(2)
s_p2_['lag_3'] = s_p2_['P2_Harmonic'].shift(3)

# Create rolling window features
s_p2_['rolling_mean_3'] = s_p2_['P2_Harmonic'].rolling(window=3).mean()
s_p2_['rolling_std_3'] = s_p2_['P2_Harmonic'].rolling(window=3).std()
s_p2_['rolling_var_3'] = s_p2_['P2_Harmonic'].rolling(window=3).var()

# Dropna
s_p2_.dropna(inplace=True)

# Sort index
s_p2_ = s_p2_.sort_index()

# Feature creation and extraction.
sp2_X = s_p2_.drop(columns=['P2_Harmonic'])
sp2_y = s_p2_['P2_Harmonic']

# Train the SVR Model
s_p2_SVR = SVR(kernel='rbf', C=1.3, epsilon=0.3)
s_p2_SVR.fit(sp2_X, sp2_y)

# Make predictions
s_p2_['Predictions'] = s_p2_SVR.predict(sp2_X)

# Evaluate Accuracy
p2_accuracy = 100 - mape(s_p2_['P2_Harmonic'], s_p2_['Predictions'])

# Make plots.
ax = s_p2_[['P2_Harmonic']].plot(figsize=(15,5), color=color_pal[-1], title="Credit Union - P2 Phase Prediction vs. True Data")
s_p2_['Predictions'].plot(ax=ax, style='-', color=color_pal[-2])

accur = f'{p2_accuracy:.2f}%'
ax.set_xlabel('Datetime', rotation=0)
ax.legend(['P2 True Data', 'P2 Predicted'])

# Add text annotation at a specific point
ax.text(0.05, 0.95, f'Accuracy: {accur}', transform=ax.transAxes, fontsize=12,
        verticalalignment='top', bbox=dict(boxstyle='round', facecolor='white', alpha=0.5))

plt.savefig('ccu_p2__true_vs_predicted.jpg', dpi=307)
plt.show()

# %% [markdown]
# <br>
#
# ### Phase 3 (P3)

# %%
# Create a deep copy
s_p3_ = s_p3.copy(deep=True)

# Create lags
s_p3_['lag_1'] = s_p3_['P3_Harmonic'].shift(1)
s_p3_['lag_2'] = s_p3_['P3_Harmonic'].shift(2)
s_p3_['lag_3'] = s_p3_['P3_Harmonic'].shift(3)

# Create rolling window features
s_p3_['rolling_mean_3'] = s_p3_['P3_Harmonic'].rolling(window=3).mean()
s_p3_['rolling_std_3'] = s_p3_['P3_Harmonic'].rolling(window=3).std()
s_p3_['rolling_var_3'] = s_p3_['P3_Harmonic'].rolling(window=3).var()

# Dropna
s_p3_.dropna(inplace=True)

# Sort index
s_p3_ = s_p3_.sort_index()

# Feature creation and extraction.
sp3_X = s_p3_.drop(columns=['P3_Harmonic'])
sp3_y = s_p3_['P3_Harmonic']

# Train the SVR Model
s_p3_SVR = SVR(kernel='rbf', C=1.3, epsilon=0.3)
s_p3_SVR.fit(sp3_X, sp3_y)

# Make predictions
s_p3_['Predictions'] = s_p3_SVR.predict(sp3_X)

# Evaluate Accuracy
p3_accuracy = 100 - mape(s_p3_['P3_Harmonic'], s_p3_['Predictions'])

# Make plots.
ax = s_p3_[['P3_Harmonic']].plot(figsize=(15,5), color=color_pal[1], title="Credit Union - Phase Prediction vs. True Data")
s_p3_['Predictions'].plot(ax=ax, style='-', color=color_pal[2])

accur = f'{p3_accuracy:.2f}%'
ax.set_xlabel('Datetime', rotation=0)
ax.legend(['P3 True Data', 'P3 Predicted'])

# Add text annotation at a specific point
ax.text(0.05, 0.95, f'Accuracy: {accur}', transform=ax.transAxes, fontsize=12,
        verticalalignment='top', bbox=dict(boxstyle='round', facecolor='white', alpha=0.5))

plt.savefig('ccu_p3__true_vs_predicted.jpg', dpi=307)
plt.show()

# %% [markdown]
# <br><br><br>
# ## Prediction on Future and Unseen Data

# %% [markdown]
# ### Phase 1 (P1)

# %%
# The Seed
s_p1_seed = s_p1_.tail(10).copy(deep=True)
s_p1_seed.head(3)
# Out:
#                      P1_Harmonic  hour  minute  dayofweek     lag_1     lag_2  \
# Datetime
# 2023-09-06 11:32:00     8.935678    11      32          2  9.098750  8.657705
# 2023-09-02 11:42:00     7.862571    11      42          5  8.935678  9.098750
# 2023-09-06 11:52:00     8.811168    11      52          2  7.862571  8.935678
#
#                         lag_3  rolling_mean_3  rolling_std_3  rolling_var_3  \
# Datetime
# 2023-09-06 11:32:00  8.621191        8.897378       0.223003      26.692133
# 2023-09-02 11:42:00  8.657705        8.632333       0.671601      25.896999
# 2023-09-06 11:52:00  9.098750        8.536472       0.586927      25.609417
#
#                      Predictions
# Datetime
# 2023-09-06 11:32:00     8.975680
# 2023-09-02 11:42:00     8.167661
# 2023-09-06 11:52:00     8.561138

# %%
# number of years to predict for.
sp1_n = 5

sp1_start_date = datetime.strptime(str(list(s_p1_seed.index)[0]), '%Y-%m-%d %H:%M:%S')
sp1_end_date = sp1_start_date + relativedelta(years=sp1_n)

sp1_dates = np.array(s_p1_seed.index.astype(str))
sp1_harmonics = np.array(s_p1_seed['P1_Harmonic'].values)
sp1_hr = np.array(s_p1_seed['hour'].values)
sp1_min = np.array(s_p1_seed['minute'].values)
sp1_dow = np.array(s_p1_seed['dayofweek'].values)
sp1_lag_1 = np.array(s_p1_seed['lag_1'].values)
sp1_lag_2 = np.array(s_p1_seed['lag_2'].values)
sp1_lag_3 = np.array(s_p1_seed['lag_3'].values)
sp1_roll_mean_3 = np.array(s_p1_seed['rolling_mean_3'].values)
sp1_roll_std_3 = np.array(s_p1_seed['rolling_std_3'].values)
sp1_roll_var_3 = np.array(s_p1_seed['rolling_var_3'].values)
sp1_y_pred = np.array(s_p1_seed['Predictions'].values)

# Pre-allocate memory for future values
sp1_prediction_horizon = int((sp1_end_date - sp1_start_date).total_seconds() // 600)  # 10-minute increments
sp1_future_dates = np.empty(sp1_prediction_horizon, dtype="U19")  # Pre-allocate date array (string format)
sp1_future_p1_h = np.empty(sp1_prediction_horizon)
sp1_future_lag_1 = np.empty(sp1_prediction_horizon)
sp1_future_lag_2 = np.empty(sp1_prediction_horizon)
sp1_future_lag_3 = np.empty(sp1_prediction_horizon)
sp1_future_roll_mean_3 = np.empty(sp1_prediction_horizon)
sp1_future_roll_std_3 = np.empty(sp1_prediction_horizon)
sp1_future_roll_var_3 = np.empty(sp1_prediction_horizon)
sp1_future_hr = np.empty(sp1_prediction_horizon, dtype=int)
sp1_future_min = np.empty(sp1_prediction_horizon, dtype=int)
sp1_future_dow = np.empty(sp1_prediction_horizon, dtype=int)
sp1_future_y_pred = np.empty(sp1_prediction_horizon)

# Initialize current time from the last date
sp1_current_date = datetime.strptime(sp1_dates[-1], '%Y-%m-%d %H:%M:%S')

i = 0

# %%
def sp1_timer():
    start_time = time.time()
    while not task1_done:
        elapsed_time = time.time() - start_time
        hours, rem = divmod(elapsed_time, 3600)
        minutes, seconds = divmod(rem, 60)
        print(f"\033[1;95mElapsed time: {int(hours):02}:{int(minutes):02}:{int(seconds):02} (Run {i:,} out of {sp1_prediction_horizon:,})", end='\r')
        time.sleep(0.00001)  # Update every second

# %%
task1_done = False

timer1_thread = threading.Thread(target=sp1_timer)
timer1_thread.start()

# Loop to generate predictions
while i < sp1_prediction_horizon:
    # Advance time by 10 minutes
    sp1_current_date += timedelta(minutes=10)
    sp1_current_hr = sp1_current_date.hour
    sp1_current_min = sp1_current_date.minute
    sp1_current_dow = sp1_current_date.weekday()
    
    # Append new values to the arrays
    sp1_future_dates[i] = sp1_current_date.strftime('%Y-%m-%d %H:%M:%S')
    sp1_future_hr[i] = sp1_current_hr
    sp1_future_min[i] = sp1_current_min
    sp1_future_dow[i] = sp1_current_dow
    sp1_future_p1_h[i] = sp1_y_pred[-1]  # Previous prediction becomes the new harmonic value
    
    # Update lag features
    sp1_future_lag_1[i] = sp1_future_p1_h[i - 1] if i > 0 else sp1_harmonics[-1]
    sp1_future_lag_2[i] = sp1_future_lag_1[i - 1] if i > 1 else sp1_lag_1[-1]
    sp1_future_lag_3[i] = sp1_future_lag_2[i - 1] if i > 2 else sp1_lag_2[-1]
    
    # Compute rolling statistics (using pre-existing values)
    sp1_window_p1_h = np.concatenate((sp1_harmonics[-2:], sp1_future_p1_h[:i+1]))[-3:]
    sp1_future_roll_mean_3[i] = np.mean(sp1_window_p1_h)
    sp1_future_roll_std_3[i] = np.std(sp1_window_p1_h)
    sp1_future_roll_var_3[i] = np.var(sp1_window_p1_h)
    
    # Construct the input data for the model prediction
    sp1_X = pd.DataFrame({
        'hour': np.concatenate((sp1_hr, sp1_future_hr[:i+1])),
        'minute': np.concatenate((sp1_min, sp1_future_min[:i+1])),
        'dayofweek': np.concatenate((sp1_dow, sp1_future_dow[:i+1])),
        'lag_1': np.concatenate((sp1_lag_1, sp1_future_lag_1[:i+1])),
        'lag_2': np.concatenate((sp1_lag_2, sp1_future_lag_2[:i+1])),
        'lag_3': np.concatenate((sp1_lag_3, sp1_future_lag_3[:i+1])),
        'rolling_mean_3': np.concatenate((sp1_roll_mean_3, sp1_future_roll_mean_3[:i+1])),
        'rolling_std_3': np.concatenate((sp1_roll_std_3, sp1_future_roll_std_3[:i+1])),
        'rolling_var_3': np.concatenate((sp1_roll_var_3, sp1_future_roll_var_3[:i+1]))
    })
    
    # Predict and append the result
    y_pred1 = s_p1_SVR.predict(sp1_X.iloc[-1:])
    sp1_future_y_pred[i] = y_pred1

    # Update _y_pred for future iterations
    sp1_y_pred = np.append(sp1_y_pred, y_pred1)

    i += 1

task1_done = True
timer1_thread.join()
i
# Out:
# Elapsed time: 00:00:20 (Run 26,382 out of 263,088)
# IOPub data rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_data_rate_limit`.
#
# Current values:
# ServerApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# ServerApp.rate_limit_window=3.0 (secs)
# Elapsed time: 00:00:24 (Run 29,837 out of 263,088)
# IOPub data rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_data_rate_limit`.
#
# Current values:
# ServerApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# ServerApp.rate_limit_window=3.0 (secs)
# Elapsed time: 00:00:27 (Run 33,136 out of 263,088)
# IOPub data rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_data_rate_limit`.
#
# Current values:
# ServerApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# ServerApp.rate_limit_window=3.0 (secs)
# Elapsed time: 00:00:30 (Run 36,284 out of 263,088)
# IOPub data rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_data_rate_limit`.
#
# Current values:
# ServerApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# ServerApp.rate_limit_window=3.0 (secs)
# Elapsed time: 00:00:34 (Run 39,308 out of 263,088)
# IOPub data rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_data_rate_limit`.
#
# Current values:
# ServerApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# ServerApp.rate_limit_window=3.0 (secs)
# Elapsed time: 00:00:37 (Run 42,259 out of 263,088)
# IOPub data rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_data_rate_limit`.
#
# Current values:
# ServerApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# ServerApp.rate_limit_window=3.0 (secs)
# Elapsed time: 00:00:41 (Run 45,074 out of 263,088)
# IOPub data rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_data_rate_limit`.
#
# Current values:
# ServerApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# ServerApp.rate_limit_window=3.0 (secs)
# Elapsed time: 00:00:44 (Run 47,616 out of 263,088)
# IOPub data rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_data_rate_limit`.
#
# Current values:
# ServerApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# ServerApp.rate_limit_window=3.0 (secs)
# Elapsed time: 00:00:47 (Run 50,213 out of 263,088)
# IOPub data rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_data_rate_limit`.
#
# Current values:
# ServerApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# ServerApp.rate_limit_window=3.0 (secs)
# Elapsed time: 00:00:51 (Run 52,765 out of 263,088)
# IOPub data rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_data_rate_limit`.
#
# Current values:
# ServerApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# ServerApp.rate_limit_window=3.0 (secs)
# Elapsed time: 00:00:54 (Run 55,244 out of 263,088)
# IOPub data rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_data_rate_limit`.
#
# Current values:
# ServerApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# ServerApp.rate_limit_window=3.0 (secs)
# Elapsed time: 00:00:58 (Run 57,659 out of 263,088)
# IOPub data rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_data_rate_limit`.
#
# Current values:
# ServerApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# ServerApp.rate_limit_window=3.0 (secs)
# Elapsed time: 00:01:01 (Run 60,006 out of 263,088)
# IOPub data rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_data_rate_limit`.
#
# Current values:
# ServerApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# ServerApp.rate_limit_window=3.0 (secs)
# Elapsed time: 00:01:04 (Run 62,173 out of 263,088)
# IOPub data rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_data_rate_limit`.
#
# Current values:
# ServerApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# ServerApp.rate_limit_window=3.0 (secs)
# Elapsed time: 00:01:08 (Run 64,275 out of 263,088)
# IOPub data rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_data_rate_limit`.
#
# Current values:
# ServerApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# ServerApp.rate_limit_window=3.0 (secs)
# Elapsed time: 00:01:11 (Run 66,315 out of 263,088)
# IOPub data rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_data_rate_limit`.
#
# Current values:
# ServerApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# ServerApp.rate_limit_window=3.0 (secs)
# Elapsed time: 00:01:14 (Run 68,329 out of 263,088)
# IOPub data rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_data_rate_limit`.
#
# Current values:
# ServerApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# ServerApp.rate_limit_window=3.0 (secs)
# Elapsed time: 00:01:18 (Run 70,389 out of 263,088)
# IOPub data rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_data_rate_limit`.
#
# Current values:
# ServerApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# ServerApp.rate_limit_window=3.0 (secs)
# Elapsed time: 00:01:21 (Run 72,436 out of 263,088)
# IOPub data rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_data_rate_limit`.
#
# Current values:
# ServerApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# ServerApp.rate_limit_window=3.0 (secs)
# Elapsed time: 00:01:24 (Run 74,467 out of 263,088)
# IOPub data rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_data_rate_limit`.
#
# Current values:
# ServerApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# ServerApp.rate_limit_window=3.0 (secs)
# Elapsed time: 00:01:28 (Run 76,462 out of 263,088)
# IOPub data rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_data_rate_limit`.
#
# Current values:
# ServerApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# ServerApp.rate_limit_window=3.0 (secs)
# Elapsed time: 00:01:31 (Run 78,416 out of 263,088)
# IOPub data rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_data_rate_limit`.
#
# Current values:
# ServerApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# ServerApp.rate_limit_window=3.0 (secs)
# Elapsed time: 00:01:35 (Run 80,309 out of 263,088)
# IOPub data rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_data_rate_limit`.
#
# Current values:
# ServerApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# ServerApp.rate_limit_window=3.0 (secs)
# Elapsed time: 00:01:38 (Run 81,796 out of 263,088)
# IOPub data rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_data_rate_limit`.
#
# Current values:
# ServerApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# ServerApp.rate_limit_window=3.0 (secs)
# Elapsed time: 00:01:42 (Run 83,432 out of 263,088)
# IOPub data rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_data_rate_limit`.
#
# Current values:
# ServerApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# ServerApp.rate_limit_window=3.0 (secs)
# Elapsed time: 00:01:45 (Run 84,873 out of 263,088)
# IOPub data rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_data_rate_limit`.
#
# Current values:
# ServerApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# ServerApp.rate_limit_window=3.0 (secs)
# Elapsed time: 00:01:48 (Run 86,413 out of 263,088)
# IOPub data rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_data_rate_limit`.
#
# Current values:
# ServerApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# ServerApp.rate_limit_window=3.0 (secs)
# Elapsed time: 00:01:52 (Run 88,064 out of 263,088)
# IOPub data rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_data_rate_limit`.
#
# Current values:
# ServerApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# ServerApp.rate_limit_window=3.0 (secs)
# Elapsed time: 00:01:55 (Run 89,753 out of 263,088)
# IOPub data rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_data_rate_limit`.
#
# Current values:
# ServerApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# ServerApp.rate_limit_window=3.0 (secs)
# Elapsed time: 00:01:59 (Run 91,384 out of 263,088)
# IOPub data rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_data_rate_limit`.
#
# Current values:
# ServerApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# ServerApp.rate_limit_window=3.0 (secs)
# Elapsed time: 00:02:02 (Run 92,985 out of 263,088)
# IOPub data rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_data_rate_limit`.
#
# Current values:
# ServerApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# ServerApp.rate_limit_window=3.0 (secs)
# Elapsed time: 00:02:06 (Run 94,567 out of 263,088)
# IOPub data rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_data_rate_limit`.
#
# Current values:
# ServerApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# ServerApp.rate_limit_window=3.0 (secs)
# Elapsed time: 00:02:09 (Run 96,132 out of 263,088)
# IOPub data rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_data_rate_limit`.
#
# Current values:
# ServerApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# ServerApp.rate_limit_window=3.0 (secs)
# Elapsed time: 00:02:13 (Run 97,687 out of 263,088)
# IOPub data rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_data_rate_limit`.
#
# Current values:
# ServerApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# ServerApp.rate_limit_window=3.0 (secs)
# Elapsed time: 00:02:16 (Run 99,189 out of 263,088)
# IOPub data rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_data_rate_limit`.
#
# Current values:
# ServerApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# ServerApp.rate_limit_window=3.0 (secs)
# Elapsed time: 00:02:19 (Run 100,533 out of 263,088)
# IOPub data rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_data_rate_limit`.
#
# Current values:
# ServerApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# ServerApp.rate_limit_window=3.0 (secs)
# Elapsed time: 00:02:22 (Run 102,017 out of 263,088)
# IOPub data rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_data_rate_limit`.
#
# Current values:
# ServerApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# ServerApp.rate_limit_window=3.0 (secs)
# Elapsed time: 00:02:26 (Run 103,463 out of 263,088)
# IOPub data rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_data_rate_limit`.
#
# Current values:
# ServerApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# ServerApp.rate_limit_window=3.0 (secs)
# Elapsed time: 00:02:29 (Run 104,851 out of 263,088)
# IOPub data rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_data_rate_limit`.
#
# Current values:
# ServerApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# ServerApp.rate_limit_window=3.0 (secs)
# Elapsed time: 00:02:32 (Run 106,231 out of 263,088)
# IOPub data rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_data_rate_limit`.
#
# Current values:
# ServerApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# ServerApp.rate_limit_window=3.0 (secs)
# Elapsed time: 00:02:35 (Run 107,572 out of 263,088)
# IOPub data rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_data_rate_limit`.
#
# Current values:
# ServerApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# ServerApp.rate_limit_window=3.0 (secs)
# Elapsed time: 00:02:39 (Run 108,993 out of 263,088)
# IOPub data rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_data_rate_limit`.
#
# Current values:
# ServerApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# ServerApp.rate_limit_window=3.0 (secs)
# Elapsed time: 00:02:42 (Run 110,339 out of 263,088)
# IOPub data rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_data_rate_limit`.
#
# Current values:
# ServerApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# ServerApp.rate_limit_window=3.0 (secs)
# Elapsed time: 00:02:46 (Run 111,707 out of 263,088)
# IOPub data rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_data_rate_limit`.
#
# Current values:
# ServerApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# ServerApp.rate_limit_window=3.0 (secs)
# Elapsed time: 00:02:49 (Run 112,963 out of 263,088)
# IOPub data rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_data_rate_limit`.
#
# Current values:
# ServerApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# ServerApp.rate_limit_window=3.0 (secs)
# Elapsed time: 00:02:52 (Run 114,263 out of 263,088)
# IOPub data rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_data_rate_limit`.
#
# Current values:
# ServerApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# ServerApp.rate_limit_window=3.0 (secs)
# Elapsed time: 00:02:55 (Run 115,550 out of 263,088)
# IOPub data rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_data_rate_limit`.
#
# Current values:
# ServerApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# ServerApp.rate_limit_window=3.0 (secs)
# Elapsed time: 00:02:59 (Run 116,857 out of 263,088)
# IOPub data rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_data_rate_limit`.
#
# Current values:
# ServerApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# ServerApp.rate_limit_window=3.0 (secs)
# Elapsed time: 00:03:02 (Run 118,104 out of 263,088)
# IOPub data rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_data_rate_limit`.
#
# Current values:
# ServerApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# ServerApp.rate_limit_window=3.0 (secs)
# Elapsed time: 00:03:05 (Run 119,351 out of 263,088)
# IOPub data rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_data_rate_limit`.
#
# Current values:
# ServerApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# ServerApp.rate_limit_window=3.0 (secs)
# Elapsed time: 00:03:08 (Run 120,584 out of 263,088)
# IOPub data rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_data_rate_limit`.
#
# Current values:
# ServerApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# ServerApp.rate_limit_window=3.0 (secs)
# Elapsed time: 00:03:12 (Run 121,837 out of 263,088)
# IOPub data rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_data_rate_limit`.
#
# Current values:
# ServerApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# ServerApp.rate_limit_window=3.0 (secs)
# Elapsed time: 00:03:15 (Run 123,058 out of 263,088)
# IOPub data rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_data_rate_limit`.
#
# Current values:
# ServerApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# ServerApp.rate_limit_window=3.0 (secs)
# Elapsed time: 00:03:18 (Run 124,303 out of 263,088)
# IOPub data rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_data_rate_limit`.
#
# Current values:
# ServerApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# ServerApp.rate_limit_window=3.0 (secs)
# Elapsed time: 00:03:22 (Run 125,562 out of 263,088)
# IOPub data rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_data_rate_limit`.
#
# Current values:
# ServerApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# ServerApp.rate_limit_window=3.0 (secs)
# Elapsed time: 00:03:25 (Run 126,794 out of 263,088)
# IOPub data rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_data_rate_limit`.
#
# Current values:
# ServerApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# ServerApp.rate_limit_window=3.0 (secs)
# Elapsed time: 00:03:28 (Run 127,984 out of 263,088)
# IOPub data rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_data_rate_limit`.
#
# Current values:
# ServerApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# ServerApp.rate_limit_window=3.0 (secs)
# Elapsed time: 00:03:32 (Run 129,129 out of 263,088)
# IOPub data rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_data_rate_limit`.
#
# Current values:
# ServerApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# ServerApp.rate_limit_window=3.0 (secs)
# Elapsed time: 00:03:35 (Run 130,287 out of 263,088)
# IOPub data rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_data_rate_limit`.
#
# Current values:
# ServerApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# ServerApp.rate_limit_window=3.0 (secs)
# Elapsed time: 00:03:38 (Run 131,431 out of 263,088)
# IOPub data rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_data_rate_limit`.
#
# Current values:
# ServerApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# ServerApp.rate_limit_window=3.0 (secs)
# Elapsed time: 00:03:41 (Run 132,577 out of 263,088)
# IOPub data rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_data_rate_limit`.
#
# Current values:
# ServerApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# ServerApp.rate_limit_window=3.0 (secs)
# Elapsed time: 00:03:45 (Run 133,719 out of 263,088)
# IOPub data rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_data_rate_limit`.
#
# Current values:
# ServerApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# ServerApp.rate_limit_window=3.0 (secs)
# Elapsed time: 00:03:48 (Run 134,862 out of 263,088)
# IOPub data rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_data_rate_limit`.
#
# Current values:
# ServerApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# ServerApp.rate_limit_window=3.0 (secs)
# Elapsed time: 00:03:51 (Run 135,976 out of 263,088)
# IOPub data rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_data_rate_limit`.
#
# Current values:
# ServerApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# ServerApp.rate_limit_window=3.0 (secs)
# Elapsed time: 00:03:54 (Run 137,081 out of 263,088)
# IOPub data rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_data_rate_limit`.
#
# Current values:
# ServerApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# ServerApp.rate_limit_window=3.0 (secs)
# Elapsed time: 00:03:58 (Run 138,185 out of 263,088)
# IOPub data rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_data_rate_limit`.
#
# Current values:
# ServerApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# ServerApp.rate_limit_window=3.0 (secs)
# Elapsed time: 00:04:01 (Run 139,275 out of 263,088)
# IOPub data rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_data_rate_limit`.
#
# Current values:
# ServerApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# ServerApp.rate_limit_window=3.0 (secs)
# Elapsed time: 00:04:04 (Run 140,294 out of 263,088)
# IOPub data rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_data_rate_limit`.
#
# Current values:
# ServerApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# ServerApp.rate_limit_window=3.0 (secs)
# Elapsed time: 00:04:08 (Run 141,497 out of 263,088)
# IOPub data rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_data_rate_limit`.
#
# Current values:
# ServerApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# ServerApp.rate_limit_window=3.0 (secs)
# Elapsed time: 00:04:15 (Run 142,220 out of 263,088)
# IOPub data rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_data_rate_limit`.
#
# Current values:
# ServerApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# ServerApp.rate_limit_window=3.0 (secs)
# Elapsed time: 00:04:19 (Run 143,084 out of 263,088)
# IOPub data rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_data_rate_limit`.
#
# Current values:
# ServerApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# ServerApp.rate_limit_window=3.0 (secs)
# Elapsed time: 00:04:22 (Run 144,154 out of 263,088)
# IOPub data rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_data_rate_limit`.
#
# Current values:
# ServerApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# ServerApp.rate_limit_window=3.0 (secs)
# Elapsed time: 00:04:25 (Run 145,229 out of 263,088)
# IOPub data rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_data_rate_limit`.
#
# Current values:
# ServerApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# ServerApp.rate_limit_window=3.0 (secs)
# Elapsed time: 00:04:29 (Run 146,304 out of 263,088)
# IOPub data rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_data_rate_limit`.
#
# Current values:
# ServerApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# ServerApp.rate_limit_window=3.0 (secs)
# Elapsed time: 00:04:32 (Run 147,374 out of 263,088)
# IOPub data rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_data_rate_limit`.
#
# Current values:
# ServerApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# ServerApp.rate_limit_window=3.0 (secs)
# Elapsed time: 00:04:35 (Run 148,305 out of 263,088)
# IOPub data rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_data_rate_limit`.
#
# Current values:
# ServerApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# ServerApp.rate_limit_window=3.0 (secs)
# Elapsed time: 00:04:39 (Run 149,341 out of 263,088)
# IOPub data rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_data_rate_limit`.
#
# Current values:
# ServerApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# ServerApp.rate_limit_window=3.0 (secs)
# Elapsed time: 00:04:42 (Run 150,376 out of 263,088)
# IOPub data rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_data_rate_limit`.
#
# Current values:
# ServerApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# ServerApp.rate_limit_window=3.0 (secs)
# Elapsed time: 00:04:45 (Run 151,384 out of 263,088)
# IOPub data rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_data_rate_limit`.
#
# Current values:
# ServerApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# ServerApp.rate_limit_window=3.0 (secs)
# Elapsed time: 00:04:48 (Run 152,411 out of 263,088)
# IOPub data rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_data_rate_limit`.
#
# Current values:
# ServerApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# ServerApp.rate_limit_window=3.0 (secs)
# Elapsed time: 00:04:52 (Run 153,431 out of 263,088)
# IOPub data rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_data_rate_limit`.
#
# Current values:
# ServerApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# ServerApp.rate_limit_window=3.0 (secs)
# Elapsed time: 00:04:55 (Run 154,455 out of 263,088)
# IOPub data rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_data_rate_limit`.
#
# Current values:
# ServerApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# ServerApp.rate_limit_window=3.0 (secs)
# Elapsed time: 00:04:58 (Run 155,446 out of 263,088)
# IOPub data rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_data_rate_limit`.
#
# Current values:
# ServerApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# ServerApp.rate_limit_window=3.0 (secs)
# Elapsed time: 00:05:02 (Run 156,453 out of 263,088)
# IOPub data rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_data_rate_limit`.
#
# Current values:
# ServerApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# ServerApp.rate_limit_window=3.0 (secs)
# Elapsed time: 00:05:05 (Run 157,450 out of 263,088)
# IOPub data rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_data_rate_limit`.
#
# Current values:
# ServerApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# ServerApp.rate_limit_window=3.0 (secs)
# Elapsed time: 00:05:08 (Run 158,438 out of 263,088)
# IOPub data rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_data_rate_limit`.
#
# Current values:
# ServerApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# ServerApp.rate_limit_window=3.0 (secs)
# Elapsed time: 00:05:11 (Run 159,399 out of 263,088)
# IOPub data rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_data_rate_limit`.
#
# Current values:
# ServerApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# ServerApp.rate_limit_window=3.0 (secs)
# Elapsed time: 00:05:15 (Run 160,386 out of 263,088)
# IOPub data rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_data_rate_limit`.
#
# Current values:
# ServerApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# ServerApp.rate_limit_window=3.0 (secs)
# Elapsed time: 00:05:18 (Run 161,355 out of 263,088)
# IOPub data rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_data_rate_limit`.
#
# Current values:
# ServerApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# ServerApp.rate_limit_window=3.0 (secs)
# Elapsed time: 00:05:21 (Run 162,330 out of 263,088)
# IOPub data rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_data_rate_limit`.
#
# Current values:
# ServerApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# ServerApp.rate_limit_window=3.0 (secs)
# Elapsed time: 00:05:25 (Run 163,256 out of 263,088)
# IOPub data rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_data_rate_limit`.
#
# Current values:
# ServerApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# ServerApp.rate_limit_window=3.0 (secs)
# Elapsed time: 00:05:28 (Run 164,190 out of 263,088)
# IOPub data rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_data_rate_limit`.
#
# Current values:
# ServerApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# ServerApp.rate_limit_window=3.0 (secs)
# Elapsed time: 00:05:31 (Run 165,154 out of 263,088)
# IOPub data rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_data_rate_limit`.
#
# Current values:
# ServerApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# ServerApp.rate_limit_window=3.0 (secs)
# Elapsed time: 00:05:34 (Run 166,111 out of 263,088)
# IOPub data rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_data_rate_limit`.
#
# Current values:
# ServerApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# ServerApp.rate_limit_window=3.0 (secs)
# Elapsed time: 00:05:38 (Run 167,022 out of 263,088)
# IOPub data rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_data_rate_limit`.
#
# Current values:
# ServerApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# ServerApp.rate_limit_window=3.0 (secs)
# Elapsed time: 00:05:41 (Run 167,985 out of 263,088)
# IOPub data rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_data_rate_limit`.
#
# Current values:
# ServerApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# ServerApp.rate_limit_window=3.0 (secs)
# Elapsed time: 00:05:44 (Run 168,921 out of 263,088)
# IOPub data rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_data_rate_limit`.
#
# Current values:
# ServerApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# ServerApp.rate_limit_window=3.0 (secs)
# Elapsed time: 00:05:48 (Run 169,880 out of 263,088)
# IOPub data rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_data_rate_limit`.
#
# Current values:
# ServerApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# ServerApp.rate_limit_window=3.0 (secs)
# Elapsed time: 00:05:50 (Run 170,446 out of 263,088)
# IOPub data rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_data_rate_limit`.
#
# Current values:
# ServerApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# ServerApp.rate_limit_window=3.0 (secs)
# Elapsed time: 00:05:52 (Run 170,863 out of 263,088)
# IOPub data rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_data_rate_limit`.
#
# Current values:
# ServerApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# ServerApp.rate_limit_window=3.0 (secs)
# Elapsed time: 00:05:54 (Run 171,347 out of 263,088)
# IOPub data rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_data_rate_limit`.
#
# Current values:
# ServerApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# ServerApp.rate_limit_window=3.0 (secs)
# Elapsed time: 00:05:55 (Run 171,775 out of 263,088)
# IOPub data rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_data_rate_limit`.
#
# Current values:
# ServerApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# ServerApp.rate_limit_window=3.0 (secs)
# Elapsed time: 00:05:57 (Run 172,257 out of 263,088)
# IOPub data rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_data_rate_limit`.
#
# Current values:
# ServerApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# ServerApp.rate_limit_window=3.0 (secs)
# Elapsed time: 00:05:59 (Run 172,662 out of 263,088)
# IOPub data rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_data_rate_limit`.
#
# Current values:
# ServerApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# ServerApp.rate_limit_window=3.0 (secs)
# Elapsed time: 00:06:01 (Run 173,017 out of 263,088)
# IOPub data rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_data_rate_limit`.
#
# Current values:
# ServerApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# ServerApp.rate_limit_window=3.0 (secs)
# Elapsed time: 00:06:02 (Run 173,401 out of 263,088)
# IOPub data rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_data_rate_limit`.
#
# Current values:
# ServerApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# ServerApp.rate_limit_window=3.0 (secs)
# Elapsed time: 00:06:04 (Run 173,868 out of 263,088)
# IOPub data rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_data_rate_limit`.
#
# Current values:
# ServerApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# ServerApp.rate_limit_window=3.0 (secs)
# Elapsed time: 00:06:05 (Run 174,226 out of 263,088)
# IOPub data rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_data_rate_limit`.
#
# Current values:
# ServerApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# ServerApp.rate_limit_window=3.0 (secs)
# Elapsed time: 00:06:07 (Run 174,677 out of 263,088)
# IOPub data rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_data_rate_limit`.
#
# Current values:
# ServerApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# ServerApp.rate_limit_window=3.0 (secs)
# Elapsed time: 00:06:09 (Run 175,034 out of 263,088)
# IOPub data rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_data_rate_limit`.
#
# Current values:
# ServerApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# ServerApp.rate_limit_window=3.0 (secs)
# Elapsed time: 00:06:10 (Run 175,503 out of 263,088)
# IOPub data rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_data_rate_limit`.
#
# Current values:
# ServerApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# ServerApp.rate_limit_window=3.0 (secs)
# Elapsed time: 00:06:12 (Run 175,926 out of 263,088)
# IOPub data rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_data_rate_limit`.
#
# Current values:
# ServerApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# ServerApp.rate_limit_window=3.0 (secs)
# Elapsed time: 00:06:14 (Run 176,408 out of 263,088)
# IOPub data rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_data_rate_limit`.
#
# Current values:
# ServerApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# ServerApp.rate_limit_window=3.0 (secs)
# Elapsed time: 00:06:16 (Run 176,832 out of 263,088)
# IOPub data rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_data_rate_limit`.
#
# Current values:
# ServerApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# ServerApp.rate_limit_window=3.0 (secs)
# Elapsed time: 00:06:17 (Run 177,233 out of 263,088)
# IOPub data rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_data_rate_limit`.
#
# Current values:
# ServerApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# ServerApp.rate_limit_window=3.0 (secs)
# Elapsed time: 00:06:19 (Run 177,649 out of 263,088)
# IOPub data rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_data_rate_limit`.
#
# Current values:
# ServerApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# ServerApp.rate_limit_window=3.0 (secs)
# Elapsed time: 00:06:21 (Run 178,094 out of 263,088)
# IOPub data rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_data_rate_limit`.
#
# Current values:
# ServerApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# ServerApp.rate_limit_window=3.0 (secs)
# Elapsed time: 00:06:22 (Run 178,513 out of 263,088)
# IOPub data rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_data_rate_limit`.
#
# Current values:
# ServerApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# ServerApp.rate_limit_window=3.0 (secs)
# Elapsed time: 00:06:24 (Run 178,969 out of 263,088)
# IOPub data rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_data_rate_limit`.
#
# Current values:
# ServerApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# ServerApp.rate_limit_window=3.0 (secs)
# Elapsed time: 00:06:26 (Run 179,358 out of 263,088)
# IOPub data rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_data_rate_limit`.
#
# Current values:
# ServerApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# ServerApp.rate_limit_window=3.0 (secs)
# Elapsed time: 00:06:28 (Run 179,816 out of 263,088)
# IOPub data rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_data_rate_limit`.
#
# Current values:
# ServerApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# ServerApp.rate_limit_window=3.0 (secs)
# Elapsed time: 00:06:29 (Run 180,225 out of 263,088)
# IOPub data rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_data_rate_limit`.
#
# Current values:
# ServerApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# ServerApp.rate_limit_window=3.0 (secs)
# Elapsed time: 00:06:31 (Run 180,684 out of 263,088)
# IOPub data rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_data_rate_limit`.
#
# Current values:
# ServerApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# ServerApp.rate_limit_window=3.0 (secs)
# Elapsed time: 00:06:33 (Run 181,100 out of 263,088)
# IOPub data rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_data_rate_limit`.
#
# Current values:
# ServerApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# ServerApp.rate_limit_window=3.0 (secs)
# Elapsed time: 00:06:35 (Run 181,579 out of 263,088)
# IOPub data rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_data_rate_limit`.
#
# Current values:
# ServerApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# ServerApp.rate_limit_window=3.0 (secs)
# Elapsed time: 00:06:36 (Run 181,975 out of 263,088)
# IOPub data rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_data_rate_limit`.
#
# Current values:
# ServerApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# ServerApp.rate_limit_window=3.0 (secs)
# Elapsed time: 00:06:38 (Run 182,435 out of 263,088)
# IOPub data rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_data_rate_limit`.
#
# Current values:
# ServerApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# ServerApp.rate_limit_window=3.0 (secs)
# Elapsed time: 00:06:40 (Run 182,836 out of 263,088)
# IOPub data rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_data_rate_limit`.
#
# Current values:
# ServerApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# ServerApp.rate_limit_window=3.0 (secs)
# Elapsed time: 00:06:42 (Run 183,304 out of 263,088)
# IOPub data rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_data_rate_limit`.
#
# Current values:
# ServerApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# ServerApp.rate_limit_window=3.0 (secs)
# ...
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_data_rate_limit`.
#
# Current values:
# ServerApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# ServerApp.rate_limit_window=3.0 (secs)
# Elapsed time: 00:10:52 (Run 236,231 out of 263,088)
# IOPub data rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_data_rate_limit`.
#
# Current values:
# ServerApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# ServerApp.rate_limit_window=3.0 (secs)
# Elapsed time: 00:10:55 (Run 236,828 out of 263,088)
# IOPub data rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_data_rate_limit`.
#
# Current values:
# ServerApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# ServerApp.rate_limit_window=3.0 (secs)
# Elapsed time: 00:10:59 (Run 237,516 out of 263,088)
# IOPub data rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_data_rate_limit`.
#
# Current values:
# ServerApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# ServerApp.rate_limit_window=3.0 (secs)
# Elapsed time: 00:11:02 (Run 238,189 out of 263,088)
# IOPub data rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_data_rate_limit`.
#
# Current values:
# ServerApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# ServerApp.rate_limit_window=3.0 (secs)
# Elapsed time: 00:11:06 (Run 238,871 out of 263,088)
# IOPub data rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_data_rate_limit`.
#
# Current values:
# ServerApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# ServerApp.rate_limit_window=3.0 (secs)
# Elapsed time: 00:11:09 (Run 239,552 out of 263,088)
# IOPub data rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_data_rate_limit`.
#
# Current values:
# ServerApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# ServerApp.rate_limit_window=3.0 (secs)
# Elapsed time: 00:11:13 (Run 240,224 out of 263,088)
# IOPub data rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_data_rate_limit`.
#
# Current values:
# ServerApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# ServerApp.rate_limit_window=3.0 (secs)
# Elapsed time: 00:11:16 (Run 240,883 out of 263,088)
# IOPub data rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_data_rate_limit`.
#
# Current values:
# ServerApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# ServerApp.rate_limit_window=3.0 (secs)
# Elapsed time: 00:11:19 (Run 241,543 out of 263,088)
# IOPub data rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_data_rate_limit`.
#
# Current values:
# ServerApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# ServerApp.rate_limit_window=3.0 (secs)
# Elapsed time: 00:11:23 (Run 242,190 out of 263,088)
# IOPub data rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_data_rate_limit`.
#
# Current values:
# ServerApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# ServerApp.rate_limit_window=3.0 (secs)
# Elapsed time: 00:11:26 (Run 242,872 out of 263,088)
# IOPub data rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_data_rate_limit`.
#
# Current values:
# ServerApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# ServerApp.rate_limit_window=3.0 (secs)
# Elapsed time: 00:11:30 (Run 243,514 out of 263,088)
# IOPub data rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_data_rate_limit`.
#
# Current values:
# ServerApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# ServerApp.rate_limit_window=3.0 (secs)
# Elapsed time: 00:11:33 (Run 244,204 out of 263,088)
# IOPub data rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_data_rate_limit`.
#
# Current values:
# ServerApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# ServerApp.rate_limit_window=3.0 (secs)
# Elapsed time: 00:11:37 (Run 244,863 out of 263,088)
# IOPub data rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_data_rate_limit`.
#
# Current values:
# ServerApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# ServerApp.rate_limit_window=3.0 (secs)
# Elapsed time: 00:11:40 (Run 245,526 out of 263,088)
# IOPub data rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_data_rate_limit`.
#
# Current values:
# ServerApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# ServerApp.rate_limit_window=3.0 (secs)
# Elapsed time: 00:11:44 (Run 246,185 out of 263,088)
# IOPub data rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_data_rate_limit`.
#
# Current values:
# ServerApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# ServerApp.rate_limit_window=3.0 (secs)
# Elapsed time: 00:11:47 (Run 246,831 out of 263,088)
# IOPub data rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_data_rate_limit`.
#
# Current values:
# ServerApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# ServerApp.rate_limit_window=3.0 (secs)
# Elapsed time: 00:11:51 (Run 247,499 out of 263,088)
# IOPub data rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_data_rate_limit`.
#
# Current values:
# ServerApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# ServerApp.rate_limit_window=3.0 (secs)
# Elapsed time: 00:11:54 (Run 248,158 out of 263,088)
# IOPub data rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_data_rate_limit`.
#
# Current values:
# ServerApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# ServerApp.rate_limit_window=3.0 (secs)
# Elapsed time: 00:11:58 (Run 248,816 out of 263,088)
# IOPub data rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_data_rate_limit`.
#
# Current values:
# ServerApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# ServerApp.rate_limit_window=3.0 (secs)
# Elapsed time: 00:12:01 (Run 249,455 out of 263,088)
# IOPub data rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_data_rate_limit`.
#
# Current values:
# ServerApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# ServerApp.rate_limit_window=3.0 (secs)
# Elapsed time: 00:12:05 (Run 250,130 out of 263,088)
# IOPub data rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_data_rate_limit`.
#
# Current values:
# ServerApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# ServerApp.rate_limit_window=3.0 (secs)
# Elapsed time: 00:12:08 (Run 250,756 out of 263,088)
# IOPub data rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_data_rate_limit`.
#
# Current values:
# ServerApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# ServerApp.rate_limit_window=3.0 (secs)
# Elapsed time: 00:12:11 (Run 251,419 out of 263,088)
# IOPub data rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_data_rate_limit`.
#
# Current values:
# ServerApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# ServerApp.rate_limit_window=3.0 (secs)
# Elapsed time: 00:12:15 (Run 252,063 out of 263,088)
# IOPub data rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_data_rate_limit`.
#
# Current values:
# ServerApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# ServerApp.rate_limit_window=3.0 (secs)
# Elapsed time: 00:12:18 (Run 252,715 out of 263,088)
# IOPub data rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_data_rate_limit`.
#
# Current values:
# ServerApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# ServerApp.rate_limit_window=3.0 (secs)
# Elapsed time: 00:12:22 (Run 253,337 out of 263,088)
# IOPub data rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_data_rate_limit`.
#
# Current values:
# ServerApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# ServerApp.rate_limit_window=3.0 (secs)
# Elapsed time: 00:12:25 (Run 254,003 out of 263,088)
# IOPub data rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_data_rate_limit`.
#
# Current values:
# ServerApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# ServerApp.rate_limit_window=3.0 (secs)
# Elapsed time: 00:12:29 (Run 254,631 out of 263,088)
# IOPub data rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_data_rate_limit`.
#
# Current values:
# ServerApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# ServerApp.rate_limit_window=3.0 (secs)
# Elapsed time: 00:12:32 (Run 255,288 out of 263,088)
# IOPub data rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_data_rate_limit`.
#
# Current values:
# ServerApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# ServerApp.rate_limit_window=3.0 (secs)
# Elapsed time: 00:12:36 (Run 255,934 out of 263,088)
# IOPub data rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_data_rate_limit`.
#
# Current values:
# ServerApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# ServerApp.rate_limit_window=3.0 (secs)
# Elapsed time: 00:12:39 (Run 256,551 out of 263,088)
# IOPub data rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_data_rate_limit`.
#
# Current values:
# ServerApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# ServerApp.rate_limit_window=3.0 (secs)
# Elapsed time: 00:12:43 (Run 257,209 out of 263,088)
# IOPub data rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_data_rate_limit`.
#
# Current values:
# ServerApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# ServerApp.rate_limit_window=3.0 (secs)
# Elapsed time: 00:12:46 (Run 257,820 out of 263,088)
# IOPub data rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_data_rate_limit`.
#
# Current values:
# ServerApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# ServerApp.rate_limit_window=3.0 (secs)
# Elapsed time: 00:12:49 (Run 258,416 out of 263,088)
# IOPub data rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_data_rate_limit`.
#
# Current values:
# ServerApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# ServerApp.rate_limit_window=3.0 (secs)
# Elapsed time: 00:12:53 (Run 259,022 out of 263,088)
# IOPub data rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_data_rate_limit`.
#
# Current values:
# ServerApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# ServerApp.rate_limit_window=3.0 (secs)
# Elapsed time: 00:12:56 (Run 259,658 out of 263,088)
# IOPub data rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_data_rate_limit`.
#
# Current values:
# ServerApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# ServerApp.rate_limit_window=3.0 (secs)
# Elapsed time: 00:13:00 (Run 260,257 out of 263,088)
# IOPub data rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_data_rate_limit`.
#
# Current values:
# ServerApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# ServerApp.rate_limit_window=3.0 (secs)
# Elapsed time: 00:13:03 (Run 260,876 out of 263,088)
# IOPub data rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_data_rate_limit`.
#
# Current values:
# ServerApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# ServerApp.rate_limit_window=3.0 (secs)
# Elapsed time: 00:13:07 (Run 261,488 out of 263,088)
# IOPub data rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_data_rate_limit`.
#
# Current values:
# ServerApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# ServerApp.rate_limit_window=3.0 (secs)
# Elapsed time: 00:13:10 (Run 262,124 out of 263,088)
# IOPub data rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_data_rate_limit`.
#
# Current values:
# ServerApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# ServerApp.rate_limit_window=3.0 (secs)
# Elapsed time: 00:13:14 (Run 262,713 out of 263,088)
# IOPub data rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_data_rate_limit`.
#
# Current values:
# ServerApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# ServerApp.rate_limit_window=3.0 (secs)
# Elapsed time: 00:13:16 (Run 263,087 out of 263,088)
# 263088

# %%
task1_done = True
timer1_thread.join()
i
# Out:
# 263088

# %%
s_p1_future = pd.DataFrame({'Datetime':sp1_future_dates,
                       'P1_Harmonic':sp1_future_p1_h,
                       'hour':sp1_future_hr,
                       'minute':sp1_future_min,
                       'dayofweek':sp1_future_dow,
                       'lag_1':sp1_future_lag_1,
                       'lag_2':sp1_future_lag_2,
                       'lag_3':sp1_future_lag_3,
                       'rolling_mean_3':sp1_future_roll_mean_3,
                       'rolling_std_3':sp1_future_roll_std_3,
                       'rolling_var_3':sp1_future_roll_var_3,
                       'y_pred':sp1_future_y_pred
                      })

s_p1_future = s_p1_future.set_index('Datetime')
s_p1_future.index = pd.to_datetime(s_p1_future.index, format='%Y-%m-%d %H:%M:%S')
s_p1_future
# Out:
#                      P1_Harmonic  hour  minute  dayofweek      lag_1  \
# Datetime
# 2023-09-02 13:12:00    11.932525    13      12          5  12.002365
# 2023-09-02 13:22:00    -2.894472    13      22          5  11.932525
# 2023-09-02 13:32:00    16.902153    13      32          5  -2.894472
# 2023-09-02 13:42:00    16.602660    13      42          5  16.902153
# 2023-09-02 13:52:00    13.059023    13      52          5  16.602660
# ...                          ...   ...     ...        ...        ...
# 2028-09-02 12:22:00    17.542281    12      22          5  15.278344
# 2028-09-02 12:32:00    17.622437    12      32          5  17.542281
# 2028-09-02 12:42:00    -3.204434    12      42          5  17.622437
# 2028-09-02 12:52:00    12.427664    12      52          5  -3.204434
# 2028-09-02 13:02:00    13.507472    13       2          5  12.427664
#
#                          lag_2      lag_3  rolling_mean_3  rolling_std_3  \
# Datetime
# 2023-09-02 13:12:00  11.904785  12.224525       11.946558       0.041054
# 2023-09-02 13:22:00  11.904785  12.224525        7.013473       7.006033
# 2023-09-02 13:32:00  11.932525  12.224525        8.646735       8.409276
# 2023-09-02 13:42:00  -2.894472  11.932525       10.203447       9.262434
# 2023-09-02 13:52:00  16.902153  -2.894472       15.521278       1.745365
# ...                        ...        ...             ...            ...
# 2028-09-02 12:22:00  -0.873113  15.991537       10.649170       8.199741
# 2028-09-02 12:32:00  15.278344  -0.873113       16.814354       1.086616
# 2028-09-02 12:42:00  17.542281  15.278344       10.653428       9.799043
# 2028-09-02 12:52:00  17.622437  17.542281        8.948556       8.851282
# 2028-09-02 13:02:00  -3.204434  17.622437        7.576901       7.636290
#
#                      rolling_var_3     y_pred
# Datetime
# 2023-09-02 13:12:00       0.001685  -2.894472
# 2023-09-02 13:22:00      49.084494  16.902153
# 2023-09-02 13:32:00      70.715930  16.602660
# 2023-09-02 13:42:00      85.792685  13.059023
# 2023-09-02 13:52:00       3.046300  -0.807529
# ...                            ...        ...
# 2028-09-02 12:22:00      67.235746  17.622437
# 2028-09-02 12:32:00       1.180734  -3.204434
# 2028-09-02 12:42:00      96.021238  12.427664
# 2028-09-02 12:52:00      78.345191  13.507472
# 2028-09-02 13:02:00      58.312920  16.803513
#
# [263088 rows x 11 columns]

# %%
min(set(s_p1_future['y_pred']))
# Out:
# -3.2575483732410753

# %%
s_p1_future_kWh = np.abs(s_p1_future['y_pred']).sum()/6000
s_p1_future_kWh
# Out:
# 534.2559952468293

# %%
sp1_day = s_p1_future.loc['2028-08-15 23:33:00':'2028-08-17 15:53:00']

ax = sp1_day[['y_pred']].plot(
    figsize=(17,7), 
    label='Predicted P1 Harmonics', 
    color=color_pal[5], 
    title="Credit Union - Sample snapshot of Predicted P1 Harmonics for 15-08-2028 to 17-08-2028"
)

ax.set_xlabel('Datetime', rotation=0)

# Add text annotation at a specific point
ax.text(0.15, 0.95, f'Total P1 Harmonics: {s_p1_future_kWh:0.2f} kWh', transform=ax.transAxes, fontsize=13,
        verticalalignment='top', bbox=dict(boxstyle='round', facecolor='white', alpha=0.73))

plt.xlabel('Date')
plt.ylabel('P1 Harmonic (Predicted), W')
plt.grid(True)
plt.legend(['Predicted P1 Harmonics'])

plt.savefig('ccu_p1_predicted.jpg', dpi=307)
plt.show()

# %% [markdown]
# <br><br>

# %% [markdown]
# ### Phase 2 (P2)

# %%
# The Seed
s_p2_seed = s_p2_.tail(10).copy(deep=True)
s_p2_seed
# Out:
#                      P2_Harmonic  hour  minute  dayofweek     lag_1     lag_2  \
# Datetime
# 2023-09-06 11:32:00     8.725512    11      32          2  8.125793  7.985786
# 2023-09-02 11:42:00     8.316483    11      42          5  8.725512  8.125793
# 2023-09-06 11:52:00     7.966439    11      52          2  8.316483  8.725512
# 2023-09-06 12:02:00     7.780502    12       2          2  7.966439  8.316483
# 2023-09-06 12:12:00     8.095011    12      12          2  7.780502  7.966439
# 2023-09-06 12:22:00     8.387997    12      22          2  8.095011  7.780502
# 2023-09-06 12:32:00     8.043505    12      32          2  8.387997  8.095011
# 2023-09-06 12:42:00     8.433436    12      42          2  8.043505  8.387997
# 2023-09-06 12:52:00     8.064084    12      52          2  8.433436  8.043505
# 2023-09-02 13:02:00     7.933188    13       2          5  8.064084  8.433436
#
#                         lag_3  rolling_mean_3  rolling_std_3  rolling_var_3  \
# Datetime
# 2023-09-06 11:32:00  8.238118        8.279030       0.392950       0.154410
# 2023-09-02 11:42:00  7.985786        8.389263       0.306412       0.093888
# 2023-09-06 11:52:00  8.125793        8.336145       0.379918       0.144338
# 2023-09-06 12:02:00  8.725512        8.021141       0.272145       0.074063
# 2023-09-06 12:12:00  8.316483        7.947317       0.158124       0.025003
# 2023-09-06 12:22:00  7.966439        8.087837       0.303811       0.092301
# 2023-09-06 12:32:00  7.780502        8.175504       0.185817       0.034528
# 2023-09-06 12:42:00  8.095011        8.288313       0.213224       0.045464
# 2023-09-06 12:52:00  8.387997        8.180342       0.219428       0.048148
# 2023-09-02 13:02:00  8.043505        8.143569       0.259423       0.067300
#
#                      Predictions
# Datetime
# 2023-09-06 11:32:00     8.286206
# 2023-09-02 11:42:00     8.461905
# 2023-09-06 11:52:00     8.241891
# 2023-09-06 12:02:00     7.955043
# 2023-09-06 12:12:00     7.805137
# 2023-09-06 12:22:00     8.099849
# 2023-09-06 12:32:00     8.253300
# 2023-09-06 12:42:00     8.163473
# 2023-09-06 12:52:00     8.200669
# 2023-09-02 13:02:00     7.987691

# %%
# number of years to predict for.
sp2_n = 5

sp2_start_date = datetime.strptime(str(list(s_p2_seed.index)[0]), '%Y-%m-%d %H:%M:%S')
sp2_end_date = sp2_start_date + relativedelta(years=sp2_n)

sp2_dates = np.array(s_p2_seed.index.astype(str))
sp2_harmonics = np.array(s_p2_seed['P2_Harmonic'].values)
sp2_hr = np.array(s_p2_seed['hour'].values)
sp2_min = np.array(s_p2_seed['minute'].values)
sp2_dow = np.array(s_p2_seed['dayofweek'].values)
sp2_lag_1 = np.array(s_p2_seed['lag_1'].values)
sp2_lag_2 = np.array(s_p2_seed['lag_2'].values)
sp2_lag_3 = np.array(s_p2_seed['lag_3'].values)
sp2_roll_mean_3 = np.array(s_p2_seed['rolling_mean_3'].values)
sp2_roll_std_3 = np.array(s_p2_seed['rolling_std_3'].values)
sp2_roll_var_3 = np.array(s_p2_seed['rolling_var_3'].values)
sp2_y_pred = np.array(s_p2_seed['Predictions'].values)

# Pre-allocate memory for future values
sp2_prediction_horizon = int((sp2_end_date - sp2_start_date).total_seconds() // 600)  # 10-minute increments
sp2_future_dates = np.empty(sp2_prediction_horizon, dtype="U19")  # Pre-allocate date array (string format)
sp2_future_p2_h = np.empty(sp2_prediction_horizon)
sp2_future_lag_1 = np.empty(sp2_prediction_horizon)
sp2_future_lag_2 = np.empty(sp2_prediction_horizon)
sp2_future_lag_3 = np.empty(sp2_prediction_horizon)
sp2_future_roll_mean_3 = np.empty(sp2_prediction_horizon)
sp2_future_roll_std_3 = np.empty(sp2_prediction_horizon)
sp2_future_roll_var_3 = np.empty(sp2_prediction_horizon)
sp2_future_hr = np.empty(sp2_prediction_horizon, dtype=int)
sp2_future_min = np.empty(sp2_prediction_horizon, dtype=int)
sp2_future_dow = np.empty(sp2_prediction_horizon, dtype=int)
sp2_future_y_pred = np.empty(sp2_prediction_horizon)

# Initialize current time from the last date
sp2_current_date = datetime.strptime(sp2_dates[-1], '%Y-%m-%d %H:%M:%S')

j = 0

# %%
def sp2_timer():
    start_time = time.time()
    while not task2_done:
        elapsed_time = time.time() - start_time
        hours, rem = divmod(elapsed_time, 3600)
        minutes, seconds = divmod(rem, 60)
        print(f"\033[1;95mElapsed time: {int(hours):02}:{int(minutes):02}:{int(seconds):02} (Run {j:,} out of {sp2_prediction_horizon:,})", end='\r')
        time.sleep(0.0001)  # Update every second

# %%
task2_done = False

timer2_thread = threading.Thread(target=sp2_timer)
timer2_thread.start()

# Loop to generate predictions
while j < sp2_prediction_horizon:
    # Advance time by 10 minutes
    sp2_current_date += timedelta(minutes=10)
    sp2_current_hr = sp2_current_date.hour
    sp2_current_min = sp2_current_date.minute
    sp2_current_dow = sp2_current_date.weekday()
    
    # Append new values to the arrays
    sp2_future_dates[j] = sp2_current_date.strftime('%Y-%m-%d %H:%M:%S')
    sp2_future_hr[j] = sp2_current_hr
    sp2_future_min[j] = sp2_current_min
    sp2_future_dow[j] = sp2_current_dow
    sp2_future_p2_h[j] = sp2_y_pred[-1]  # Previous prediction becomes the new harmonic value
    
    # Update lag features
    sp2_future_lag_1[j] = sp2_future_p2_h[j - 1] if j > 0 else sp2_harmonics[-1]
    sp2_future_lag_2[j] = sp2_future_lag_1[j - 1] if j > 1 else sp2_lag_1[-1]
    sp2_future_lag_3[j] = sp2_future_lag_2[j - 1] if j > 2 else sp2_lag_2[-1]
    
    # Compute rolling statistics (using pre-existing values)
    sp2_window_p2_h = np.concatenate((sp2_harmonics[-2:], sp2_future_p2_h[:j+1]))[-3:]
    sp2_future_roll_mean_3[j] = np.mean(sp2_window_p2_h)
    sp2_future_roll_std_3[j] = np.std(sp2_window_p2_h)
    sp2_future_roll_var_3[j] = np.var(sp2_window_p2_h)
    
    # Construct the input data for the model prediction
    sp2_X = pd.DataFrame({
        'hour': np.concatenate((sp2_hr, sp2_future_hr[:j+1])),
        'minute': np.concatenate((sp2_min, sp2_future_min[:j+1])),
        'dayofweek': np.concatenate((sp2_min, sp2_future_min[:j+1])),
        'lag_1': np.concatenate((sp2_lag_1, sp2_future_lag_1[:j+1])),
        'lag_2': np.concatenate((sp2_lag_2, sp2_future_lag_2[:j+1])),
        'lag_3': np.concatenate((sp2_lag_3, sp2_future_lag_3[:j+1])),
        'rolling_mean_3': np.concatenate((sp2_roll_mean_3, sp2_future_roll_mean_3[:j+1])),
        'rolling_std_3': np.concatenate((sp2_roll_std_3, sp2_future_roll_std_3[:j+1])),
        'rolling_var_3': np.concatenate((sp2_roll_var_3, sp2_future_roll_var_3[:j+1]))
    })
    
    # Predict and append the result
    y_pred2 = s_p2_SVR.predict(sp2_X.iloc[-1:])
    sp2_future_y_pred[j] = y_pred2

    # Update _y_pred for future iterations
    sp2_y_pred = np.append(sp2_y_pred, y_pred2)

    j += 1

task2_done = True
timer2_thread.join()
j
# Out:
# Elapsed time: 00:11:08 (Run 263,087 out of 263,088)
# 263088

# %%
s_p2_future = pd.DataFrame({'Datetime':sp2_future_dates,
                       'P1_Harmonic':sp2_future_p2_h,
                       'hour':sp2_future_hr,
                       'minute':sp2_future_min,
                       'dayofweek':sp2_future_dow,
                       'lag_1':sp2_future_lag_1,
                       'lag_2':sp2_future_lag_2,
                       'lag_3':sp2_future_lag_3,
                       'rolling_mean_3':sp2_future_roll_mean_3,
                       'rolling_std_3':sp2_future_roll_std_3,
                       'rolling_var_3':sp2_future_roll_var_3,
                       'y_pred':sp2_future_y_pred
                      })

# %%
s_p2_future = s_p2_future.set_index('Datetime')
s_p2_future.index = pd.to_datetime(s_p2_future.index, format='%Y-%m-%d %H:%M:%S')
s_p2_future
# Out:
#                      P1_Harmonic  hour  minute  dayofweek     lag_1     lag_2  \
# Datetime
# 2023-09-02 13:12:00     7.987691    13      12          5  7.933188  8.064084
# 2023-09-02 13:22:00     7.820145    13      22          5  7.987691  8.064084
# 2023-09-02 13:32:00     7.819781    13      32          5  7.820145  7.987691
# 2023-09-02 13:42:00     7.816088    13      42          5  7.819781  7.820145
# 2023-09-02 13:52:00     7.854244    13      52          5  7.816088  7.819781
# ...                          ...   ...     ...        ...       ...       ...
# 2028-09-02 12:22:00     7.611508    12      22          5  7.660279  7.956848
# 2028-09-02 12:32:00     7.601603    12      32          5  7.611508  7.660279
# 2028-09-02 12:42:00     7.673781    12      42          5  7.601603  7.611508
# 2028-09-02 12:52:00     7.793965    12      52          5  7.673781  7.601603
# 2028-09-02 13:02:00     7.960912    13       2          5  7.793965  7.673781
#
#                         lag_3  rolling_mean_3  rolling_std_3  rolling_var_3  \
# Datetime
# 2023-09-02 13:12:00  8.433436        7.994988       0.053687       0.002882
# 2023-09-02 13:22:00  8.433436        7.913675       0.069778       0.004869
# 2023-09-02 13:32:00  8.433436        7.875872       0.079068       0.006252
# 2023-09-02 13:42:00  7.987691        7.818671       0.001833       0.000003
# 2023-09-02 13:52:00  7.820145        7.830037       0.017183       0.000295
# ...                       ...             ...            ...            ...
# 2028-09-02 12:22:00  7.781398        7.742878       0.152604       0.023288
# 2028-09-02 12:32:00  7.956848        7.624463       0.025646       0.000658
# 2028-09-02 12:42:00  7.660279        7.628964       0.031947       0.001021
# 2028-09-02 12:52:00  7.611508        7.689783       0.079343       0.006295
# 2028-09-02 13:02:00  7.601603        7.809553       0.117738       0.013862
#
#                        y_pred
# Datetime
# 2023-09-02 13:12:00  7.820145
# 2023-09-02 13:22:00  7.819781
# 2023-09-02 13:32:00  7.816088
# 2023-09-02 13:42:00  7.854244
# 2023-09-02 13:52:00  7.978031
# ...                       ...
# 2028-09-02 12:22:00  7.601603
# 2028-09-02 12:32:00  7.673781
# 2028-09-02 12:42:00  7.793965
# 2028-09-02 12:52:00  7.960912
# 2028-09-02 13:02:00  7.706513
#
# [263088 rows x 11 columns]

# %%
s_p2_future_kWh = np.abs(s_p2_future['y_pred']).sum()/6000
s_p2_future_kWh
# Out:
# 344.3211676105099

# %%
sp2_day = s_p2_future.loc['2028-08-15 23:33:00':'2028-08-17 15:53:00']

ax = sp2_day[['y_pred']].plot(
    figsize=(17,7), 
    label='Predicted P2 Harmonics', 
    color=color_pal[6], 
    title="Credit Union - Sample snapshot of Predicted P2 Harmonics for 15-08-2028 to 17-08-2028"
)

ax.set_xlabel('Datetime', rotation=0)

# Add text annotation at a specific point
ax.text(0.15, 0.75, f'Total P1 Harmonics: {s_p2_future_kWh:0.2f} kWh', transform=ax.transAxes, fontsize=13,
        verticalalignment='top', bbox=dict(boxstyle='round', facecolor='white', alpha=0.73))

plt.xlabel('Date')
plt.ylabel('P2 Harmonic (Predicted), W')
plt.grid(True)
plt.legend(['Predicted P2 Harmonics'])

plt.savefig('ccu_p2_predicted.jpg', dpi=307)
plt.show()

# %% [markdown]
# <br><br>

# %% [markdown]
# ### Phase 3 (P3)

# %%
# The Seed
s_p3_seed = s_p3_.tail(10).copy(deep=True)
s_p3_seed
# Out:
#                      P3_Harmonic  hour  minute  dayofweek      lag_1  \
# Datetime
# 2023-09-06 11:32:00     6.640538    11      32          2   6.712693
# 2023-09-02 11:42:00     6.519464    11      42          5   6.640538
# 2023-09-06 11:52:00     6.950516    11      52          2   6.519464
# 2023-09-06 12:02:00     7.093261    12       2          2   6.950516
# 2023-09-06 12:12:00     7.670110    12      12          2   7.093261
# 2023-09-06 12:22:00     8.313718    12      22          2   7.670110
# 2023-09-06 12:32:00     9.751546    12      32          2   8.313718
# 2023-09-06 12:42:00    11.101326    12      42          2   9.751546
# 2023-09-06 12:52:00    10.466725    12      52          2  11.101326
# 2023-09-02 13:02:00    11.002433    13       2          5  10.466725
#
#                          lag_2     lag_3  rolling_mean_3  rolling_std_3  \
# Datetime
# 2023-09-06 11:32:00   6.805950  7.814692        6.719727       0.082930
# 2023-09-02 11:42:00   6.712693  6.805950        6.624232       0.097641
# 2023-09-06 11:52:00   6.640538  6.712693        6.703506       0.222318
# 2023-09-06 12:02:00   6.519464  6.640538        6.854414       0.298726
# 2023-09-06 12:12:00   6.950516  6.519464        7.237962       0.380996
# 2023-09-06 12:22:00   7.093261  6.950516        7.692363       0.610533
# 2023-09-06 12:32:00   7.670110  7.093261        8.578458       1.065673
# 2023-09-06 12:42:00   8.313718  7.670110        9.722197       1.394036
# 2023-09-06 12:52:00   9.751546  8.313718       10.439866       0.675291
# 2023-09-02 13:02:00  11.101326  9.751546       10.856828       0.341438
#
#                      rolling_var_3  Predictions
# Datetime
# 2023-09-06 11:32:00       0.006877     6.658480
# 2023-09-02 11:42:00       0.009534     6.600884
# 2023-09-06 11:52:00       0.049425     6.485027
# 2023-09-06 12:02:00       0.089237     6.843885
# 2023-09-06 12:12:00       0.145158     7.214124
# 2023-09-06 12:22:00       0.372750     7.724208
# 2023-09-06 12:32:00       1.135659     8.762562
# 2023-09-06 12:42:00       1.943336    10.209258
# 2023-09-06 12:52:00       0.456018    10.404023
# 2023-09-02 13:02:00       0.116580    10.633997

# %%
# number of years to predict for.
sp3_n = 5

sp3_start_date = datetime.strptime(str(list(s_p3_seed.index)[0]), '%Y-%m-%d %H:%M:%S')
sp3_end_date = sp3_start_date + relativedelta(years=sp3_n)

sp3_dates = np.array(s_p3_seed.index.astype(str))
sp3_harmonics = np.array(s_p3_seed['P3_Harmonic'].values)
sp3_hr = np.array(s_p3_seed['hour'].values)
sp3_min = np.array(s_p3_seed['minute'].values)
sp3_dow = np.array(s_p3_seed['dayofweek'].values)
sp3_lag_1 = np.array(s_p3_seed['lag_1'].values)
sp3_lag_2 = np.array(s_p3_seed['lag_2'].values)
sp3_lag_3 = np.array(s_p3_seed['lag_3'].values)
sp3_roll_mean_3 = np.array(s_p3_seed['rolling_mean_3'].values)
sp3_roll_std_3 = np.array(s_p3_seed['rolling_std_3'].values)
sp3_roll_var_3 = np.array(s_p3_seed['rolling_var_3'].values)
sp3_y_pred = np.array(s_p3_seed['Predictions'].values)

# Pre-allocate memory for future values
sp3_prediction_horizon = int((sp3_end_date - sp3_start_date).total_seconds() // 600)  # 10-minute increments
sp3_future_dates = np.empty(sp3_prediction_horizon, dtype="U19")  # Pre-allocate date array (string format)
sp3_future_p3_h = np.empty(sp3_prediction_horizon)
sp3_future_lag_1 = np.empty(sp3_prediction_horizon)
sp3_future_lag_2 = np.empty(sp3_prediction_horizon)
sp3_future_lag_3 = np.empty(sp3_prediction_horizon)
sp3_future_roll_mean_3 = np.empty(sp3_prediction_horizon)
sp3_future_roll_std_3 = np.empty(sp3_prediction_horizon)
sp3_future_roll_var_3 = np.empty(sp3_prediction_horizon)
sp3_future_hr = np.empty(sp3_prediction_horizon, dtype=int)
sp3_future_min = np.empty(sp3_prediction_horizon, dtype=int)
sp3_future_dow = np.empty(sp3_prediction_horizon, dtype=int)
sp3_future_y_pred = np.empty(sp3_prediction_horizon)

# Initialize current time from the last date
sp3_current_date = datetime.strptime(sp3_dates[-1], '%Y-%m-%d %H:%M:%S')

k = 0

# %%
def sp3_timer():
    start_time = time.time()
    while not task3_done:
        elapsed_time = time.time() - start_time
        hours, rem = divmod(elapsed_time, 3600)
        minutes, seconds = divmod(rem, 60)
        print(f"\033[1;95mElapsed time: {int(hours):02}:{int(minutes):02}:{int(seconds):02} (Run {k:,} out of {sp3_prediction_horizon:,})", end='\r')
        time.sleep(0.0001)  # Update every second

# %%
task3_done = False

timer3_thread = threading.Thread(target=sp3_timer)
timer3_thread.start()

# Loop to generate predictions
while k < sp3_prediction_horizon:
    # Advance time by 10 minutes
    sp3_current_date += timedelta(minutes=10)
    sp3_current_hr = sp3_current_date.hour
    sp3_current_min = sp3_current_date.minute
    
    # Append new values to the arrays
    sp3_future_dates[k] = sp3_current_date.strftime('%Y-%m-%d %H:%M:%S')
    sp3_future_hr[k] = sp3_current_hr
    sp3_future_min[k] = sp3_current_min
    sp3_future_p3_h[k] = sp3_y_pred[-1]  # Previous prediction becomes the new harmonic value
    
    # Update lag features
    sp3_future_lag_1[k] = sp3_future_p3_h[k - 1] if k > 0 else sp3_harmonics[-1]
    sp3_future_lag_2[k] = sp3_future_lag_1[k - 1] if k > 1 else sp3_lag_1[-1]
    sp3_future_lag_3[k] = sp3_future_lag_2[k - 1] if k > 2 else sp3_lag_2[-1]

    # Compute rolling statistics (using pre-existing values)
    sp3_window_p3_h = np.concatenate((sp3_harmonics[-2:], sp3_future_p3_h[:k+1]))[-3:]
    sp3_future_roll_mean_3[k] = np.mean(sp3_window_p3_h)
    sp3_future_roll_std_3[k] = np.std(sp3_window_p3_h)

    # Construct the input data for the model prediction
    sp3_X = pd.DataFrame({
        'hour': np.concatenate((sp3_hr, sp3_future_hr[:k+1])),
        'minute': np.concatenate((sp3_min, sp3_future_min[:k+1])),
        'dayofweek': np.concatenate((sp3_dow, sp3_future_dow[:k+1])),
        'lag_1': np.concatenate((sp3_lag_1, sp3_future_lag_1[:k+1])),
        'lag_2': np.concatenate((sp3_lag_2, sp3_future_lag_2[:k+1])),
        'lag_3': np.concatenate((sp3_lag_3, sp3_future_lag_3[:k+1])),
        'rolling_mean_3': np.concatenate((sp3_roll_mean_3, sp3_future_roll_mean_3[:k+1])),
        'rolling_std_3': np.concatenate((sp3_roll_std_3, sp3_future_roll_std_3[:k+1])),
        'rolling_var_3': np.concatenate((sp3_roll_var_3, sp3_future_roll_var_3[:k+1]))
    })
    
    # Predict and append the result
    y_pred3 = s_p3_SVR.predict(sp3_X.iloc[-1:])
    sp3_future_y_pred[k] = y_pred3

    # Update _y_pred for future iterations
    sp3_y_pred = np.append(sp3_y_pred, y_pred3)

    k += 1

task3_done = True
timer3_thread.join()
k
# Out:
# Elapsed time: 00:11:10 (Run 263,087 out of 263,088)
# 263088

# %%
s_p3_future = pd.DataFrame({'Datetime':sp3_future_dates,
                       'P3_Harmonic':sp3_future_p3_h,
                       'hour':sp3_future_hr,
                       'minute':sp3_future_min,
                       'dayofweek':sp3_future_dow,
                       'lag_1':sp3_future_lag_1,
                       'lag_2':sp3_future_lag_2,
                       'lag_3':sp3_future_lag_3,
                       'rolling_mean_3':sp3_future_roll_mean_3,
                       'rolling_std_3':sp3_future_roll_std_3,
                       'rolling_var_3':sp3_future_roll_var_3,
                       'y_pred':sp3_future_y_pred
                      })

# %%
s_p3_future = s_p3_future.set_index('Datetime')
s_p3_future.index = pd.to_datetime(s_p3_future.index, format='%Y-%m-%d %H:%M:%S')
s_p3_future
# Out:
#                      P3_Harmonic  hour  minute  dayofweek      lag_1  \
# Datetime
# 2023-09-02 13:12:00    10.633997    13      12          0  11.002433
# 2023-09-02 13:22:00    10.784408    13      22          0  10.633997
# 2023-09-02 13:32:00    10.684262    13      32          0  10.784408
# 2023-09-02 13:42:00    10.789604    13      42          0  10.684262
# 2023-09-02 13:52:00    11.009049    13      52          0  10.789604
# ...                          ...   ...     ...        ...        ...
# 2028-09-02 12:22:00     3.309112    12      22          0   3.302672
# 2028-09-02 12:32:00     3.366761    12      32          0   3.309112
# 2028-09-02 12:42:00     3.323421    12      42          0   3.366761
# 2028-09-02 12:52:00     3.229058    12      52          0   3.323421
# 2028-09-02 13:02:00     3.176151    13       2          0   3.229058
#
#                          lag_2      lag_3  rolling_mean_3  rolling_std_3  \
# Datetime
# 2023-09-02 13:12:00  10.466725  11.101326       10.701052       0.223783
# 2023-09-02 13:22:00  10.466725  11.101326       10.806946       0.151255
# 2023-09-02 13:32:00  10.633997  11.101326       10.700889       0.062521
# 2023-09-02 13:42:00  10.784408  10.633997       10.752758       0.048481
# 2023-09-02 13:52:00  10.684262  10.784408       10.827638       0.135294
# ...                        ...        ...             ...            ...
# 2028-09-02 12:22:00   3.116263   3.162293        3.242683       0.089431
# 2028-09-02 12:32:00   3.302672   3.116263        3.326182       0.028814
# 2028-09-02 12:42:00   3.309112   3.302672        3.333098       0.024509
# 2028-09-02 12:52:00   3.366761   3.309112        3.306413       0.057489
# 2028-09-02 13:02:00   3.323421   3.366761        3.242876       0.060911
#
#                      rolling_var_3     y_pred
# Datetime
# 2023-09-02 13:12:00            0.0  10.784408
# 2023-09-02 13:22:00            0.0  10.684262
# 2023-09-02 13:32:00            0.0  10.789604
# 2023-09-02 13:42:00            0.0  11.009049
# 2023-09-02 13:52:00            0.0  10.714519
# ...                            ...        ...
# 2028-09-02 12:22:00            0.0   3.366761
# 2028-09-02 12:32:00            0.0   3.323421
# 2028-09-02 12:42:00            0.0   3.229058
# 2028-09-02 12:52:00            0.0   3.176151
# 2028-09-02 13:02:00            0.0   3.373415
#
# [263088 rows x 11 columns]

# %%
s_p3_future_kWh = np.abs(s_p3_future['y_pred']).sum()/6000
s_p3_future_kWh
# Out:
# 132.14479585820166

# %%
sp3_day = s_p3_future.loc['2028-08-15 23:33:00':'2028-08-17 15:53:00']

ax = sp1_day[['y_pred']].plot(
    figsize=(17,7), 
    label='Predicted P3 Harmonics', 
    color=color_pal[2], 
    title="Credit Union - Sample snapshot of Predicted P3 Harmonics for 15-08-2028 to 17-08-2028"
)

ax.set_xlabel('Datetime', rotation=0)

# Add text annotation at a specific point
ax.text(0.15, 0.95, f'Total P3 Harmonics: {s_p3_future_kWh:0.2f} kWh', transform=ax.transAxes, fontsize=13,
        verticalalignment='top', bbox=dict(boxstyle='round', facecolor='white', alpha=0.73))

plt.xlabel('Date')
plt.ylabel('P3 Harmonic (Predicted), W')
plt.grid(True)
plt.legend(['Predicted P3 Harmonics'])

plt.savefig('ccu_p3_predicted.jpg', dpi=307)
plt.show()

# %% [markdown]
# <br>

# %% [markdown]
# ### Summary information

# %%
s_tot_harmonic_5y = s_p1_future_kWh + s_p2_future_kWh + s_p3_future_kWh
print(f"Total Harmonics for Guss in 5 years: {s_tot_harmonic_5y:.02f} kWh")
# Out:
# Total Harmonics for Guss in 5 years: 1010.72 kWh

# %% [markdown]
# ### Cost in Money of Harmonics

# %%
#cost of electricity...
def energyCost(x: float, residential=True, tag='') -> float:
    """
    Arguments:
        x = Energy, kWh.
        residential
            True: Residential
            False: Non-Residential
            
        tag = ''
            slt-lv, slt-mv, slt-hv, slt-hv steel, slt-hv mines. 
            (special load tariff for non-residential customers)
        
    Returns:
        A tuple of
        (electricity_charge, lighting_levy, national_electrification_levy, service_charge, NHIL, VAT, total_charge)
    """
    
    total_charge = 0.0
    electricityCost = 0.0
    service_charge = 0.0
    lighting_levy = 0.0
    nat_elec_levy = 0.0
    VAT = 0.0; NHIL = 0.0;
    if(residential): #Residential Customer.
        
        if((x >= 0) and (x <= 30)): #lifeline customer...
            service_charge = 2.13
            electricityCost = (0.634792 * x) 
        else:
            service_charge = 10.730886
            if ((x > 30) and (x <= 300)):
                electricityCost = (0.634792 * 30) + (1.405722 * (x - 30))
            elif ((x > 300)):# and (x <= 600)):
                electricityCost = (0.634792 * 30) + (1.405722 * 270)  + (1.857432 * (x - 300))
            #elif (x > 600):
            #    electricityCost = (0.544627 * 30) + (1.157212 * 270)  + (1.501837 * 300) + (1.668708 * (x - 600))
        
        #calculating total energy cost.
        lighting_levy = 0.03 * electricityCost
        nat_elec_levy = 0.02 * electricityCost
        total_charge = electricityCost + lighting_levy + nat_elec_levy + service_charge
    
    else: #Nonresidential Customer.
        if (tag == ''):
            service_charge = 12.428245
            if ((x >= 0) and (x <= 300)):
                electricityCost = (1.269145 * x)
            elif ((x > 300)):# and (x <= 600)):
                electricityCost = (1.269145 * 300) + (1.577242 * (x - 300))
            #elif (x > 600):
            #    electricityCost = (1.088876 * 300) + (1.158681 * 300) + (1.729692 * (x - 600))
        else: #Special load tariffs.
            service_charge = 500.00
            if ('lv' in tag.lower()): 
                electricityCost = (x * 1.723461)
            elif ('mv' in tag.lower()):
                electricityCost = (x * 1.308541)
            elif ('steel' in tag.lower()):
                electricityCost = (x * 0.968627)
            elif (tag.lower() == 'mines'):
                electricityCost = (x * 3.430618)
            elif ('hv' in tag.lower()):
                electricityCost = (x * 1.373370)
            
        #other tariffs...
        lighting_levy = 0.03 * electricityCost
        nat_elec_levy = 0.02 * electricityCost
        pre_tax = lighting_levy + nat_elec_levy + service_charge + electricityCost
        NHIL = 0.05 * (pre_tax)
        VAT = 0.15 * (NHIL + pre_tax)
        total_charge = pre_tax + VAT + NHIL
                
    return total_charge

# %%
monthly_kWh = s_tot_harmonic_5y / (5*12)
total_GHS_5y = 5 * 12 * energyCost(monthly_kWh, residential=False)
print(f"For a 5 year sum of {s_tot_harmonic_5y:.02f} kWh ({monthly_kWh:.02f} kWh monthly), equivalent to GHS {total_GHS_5y:0.2f} over 5 years")
# Out:
# For a 5 year sum of 1010.72 kWh (16.85 kWh monthly), equivalent to GHS 2526.80 over 5 years

# %%
monthly_kWh = s_tot_harmonic_5y #/ (5*12)
total_GHS_5y = 5 * 12 * energyCost(monthly_kWh, residential=False)
print(f"For a 5 year sum of {s_tot_harmonic_5y:.02f} kWh ({monthly_kWh:.02f} kWh monthly), equivalent to GHS {total_GHS_5y:0.2f} over 5 years")
# Out:
# For a 5 year sum of 1010.72 kWh (1010.72 kWh monthly), equivalent to GHS 115140.33 over 5 years

# %% [markdown]
# <br><br><br>

# %% [markdown]
# ## Smooth the Patterns to Reveal the Seasonality.

# %% [markdown]
# The graphs of the predictions into the future follows the seasonality observed in the actual data. The following snapshots reveals this information.

# %%
from scipy.signal import savgol_filter

# %% [markdown]
# ### P1 using Savgol Filter

# %%
# Create a copy
s_p1_sv = s_p1.copy(deep = True)
s_p1_sv = s_p1_sv.drop(columns=['hour', 'minute', 'dayofweek'])

# %%
#Smoothening the data 3 times to see how it affects accuracy.
s_p1_sv['Smoothed'] = savgol_filter(s_p1_sv['P1_Harmonic'], window_length=7, polyorder=2)
for _ in range(1,37777):
    s_p1_sv['Smoothed'] = savgol_filter(s_p1_sv['Smoothed'], window_length=7, polyorder = 2)

s_p1_sv.plot()
# Out:
# <Axes: xlabel='Datetime'>

# %% [markdown]
# <br><br>

# %% [markdown]
# ### P2 using Savgol Filter

# %%
# Create a copy
s_p2_sv = s_p2.copy(deep = True)
s_p2_sv = s_p2_sv.drop(columns=['hour', 'minute', 'dayofweek'])

# %%
#Smoothening the data 3 times to see how it affects accuracy.
s_p2_sv['Smoothed'] = savgol_filter(s_p2_sv['P2_Harmonic'], window_length=7, polyorder=2)
for _ in range(1,30000):
    s_p2_sv['Smoothed'] = savgol_filter(s_p2_sv['Smoothed'], window_length=7, polyorder = 2)

s_p2_sv.plot()
# Out:
# <Axes: xlabel='Datetime'>

# %% [markdown]
# <br><br>

# %% [markdown]
# ### P3 using Savgol Filter

# %%
# Create a copy
s_p3_sv = s_p3.copy(deep = True)
s_p3_sv = s_p3_sv.drop(columns=['hour', 'minute', 'dayofweek'])

# %%
#Smoothening the data 3 times to see how it affects accuracy.
s_p3_sv['Smoothed'] = savgol_filter(s_p3_sv['P3_Harmonic'], window_length=7, polyorder=2)
for _ in range(1,30000):
    s_p3_sv['Smoothed'] = savgol_filter(s_p3_sv['Smoothed'], window_length=7, polyorder = 2)

s_p3_sv.plot()
# Out:
# <Axes: xlabel='Datetime'>
